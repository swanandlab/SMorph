# %%
import morphanalysis

import skimage
import matplotlib.pyplot as plt

# %%
def plot(image):
    fig, ax = plt.subplots(figsize=(10, 6))
    ax.imshow(image)
    ax.set_axis_off()
    plt.show()

# %%
cell_image = skimage.io.imread("pca data/control/4.jpg")

# %%
astrocyte = morphanalysis.Cell(cell_image)

# %%
plot(astrocyte.cleaned_image)

# %%
astrocyte.surface_area()
# Out:
# 622

# %%
entropy

# %%
complexity

# %% [markdown]
# ## Skeleton Analysis

# %%
skeleton = morphanalysis.Skeleton(cell_image)

# %%
skeleton.total_length()
# Out:
# 79

# %%
skeleton.convex_hull(plot=True)
# Out:
# 1025

# %%
skeleton.get_no_of_forks(plot=True)
# Out:
# 3

# %%
skeleton.classify_branching_structure(plot=True)

# %% [markdown]
# ## Sholl Analysis

# %%
sholl = morphanalysis.Sholl(cell_image)

# %%
sholl.sholl_results(plot=True)

# %%
sholl.polynomial_fit(plot=True)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
sholl.critical_radius()
# Out:
# Warning: Maximum number of function evaluations has been exceeded.
# -3.169126500570575e+26

# %%
sholl.critical_value()
# Out:
# Warning: Maximum number of function evaluations has been exceeded.
# 1.1721423080365249e+76

# %%
sholl.skewness()
# Out:
# 0.24046867188748372

# %%
sholl.schoenen_ramification_index()
# Out:
# Warning: Maximum number of function evaluations has been exceeded.
# 2.9303557700913123e+75

# %%
sholl.coefficient_of_determination()
# Out:
# 0.9124314844866297

# %%
sholl.sholl_regression_coefficient()
# Out:
# 0.1270539699336593

# %%
sholl.regression_intercept()
# Out:
# -0.8371247356471496
