# %%
import morphanalysis

# %%
groups_folders=["Saline", "Desipramine"]

# %%
color_dict={0:'black',1:'red'}
label={0:'Saline',1:'Desipramine'}
marker={0:'*',1:'o'}

# %%
pca = morphanalysis.pca(groups_folders, 'confocal', label)
# pca = morphanalysis.pca(groups_folders, image_type='DAB')
# Out:
# Saline/MAX_C1-SAL113_5_2.tif
# Saline/MAX_C1-SAL112_3_1.tif
# Saline/MAX_C1-SAL111_2_1.tif
# Saline/MAX_C1-SAL113_5_1.tif
# Saline/MAX_C1-SAL112_3_2.tif
# Saline/MAX_C1-SAL111_2_2.tif
# Saline/MAX_C1-SAL112_1_1.tif
# Saline/MAX_C1-SAL112_5_1.tif
# Saline/MAX_C1-SAL111_4_1.tif
# Saline/MAX_C1-SAL113_3_2.tif
# Saline/MAX_C1-SAL113_1_1.tif
# Saline/MAX_C1-SAL112_5_2.tif
# Saline/MAX_C1-SAL111_4_2.tif
# Saline/MAX_C1-SAL113_3_1.tif
# Saline/MAX_C1-SAL113_1_2.tif
# Saline/MAX_C1-SAL111_4_3.tif
# Saline/MAX_C1-SAL112_2_2.tif
# Saline/MAX_C1-SAL111_3_2.tif
# Saline/MAX_C1-SAL113_4_1.tif
# Saline/MAX_C1-SAL111_1_1.tif
# Saline/MAX_C1-SAL111_1_3.tif
# Saline/MAX_C1-SAL112_2_1.tif
# Saline/MAX_C1-SAL111_3_1.tif
# Saline/MAX_C1-SAL113_4_2.tif
# Saline/MAX_C1-SAL111_1_2.tif
# Saline/MAX_C1-SAL112_4_2.tif
# Saline/MAX_C1-SAL111_5_2.tif
# Saline/MAX_C1-SAL112_4_3.tif
# Saline/MAX_C1-SAL112_4_1.tif
# Saline/MAX_C1-SAL111_5_1.tif
# Saline/MAX_C1-SAL263_1_1.tif
# Saline/MAX_C1-SAL263_3_2.tif
# ...

# %%
pca.plot(color_dict, marker)

# %%
pca.plot_feature_significance_heatmap()

# %%
pca.plot_feature_significance_vectors()

# %% [markdown]
# ## Individual histograms

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
pca.plot_feature_histograms()
